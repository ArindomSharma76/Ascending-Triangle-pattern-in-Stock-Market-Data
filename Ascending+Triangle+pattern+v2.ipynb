# %% [markdown]
# ## Importing and Loading required libraries

# %%
import pandas as pd
import yfinance as yf
import mplfinance as mf

# %% [markdown]
# ## The next step is to download the financial data-set from yahoo finance using download function of yfinance library.
#
# The date range we are selecting varies from 1st May 2020 till today.
#
# For that, let’s fetch today’s date using pandas first and store it in a variable.
#
# Then we will pass this to the end parameter of download function.

# %%
today = pd.Timestamp('today')
today
# Out:
# Timestamp('2021-05-20 17:00:36.608969')

# %%
StockData = yf.download( 'MSFT',
                        start = '2021-01-30',
                        end = today,
                        progress = False)

# %% [markdown]
# #### Let’s now see what’s there in the data-set using head function.

# %%
StockData.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-06-29  195.779999  198.529999  193.550003  198.440002  196.990829
# 2020-06-30  197.880005  204.399994  197.740005  203.509995  202.023819
# 2020-07-01  203.139999  206.350006  201.770004  204.699997  203.205124
# 2020-07-02  205.679993  208.020004  205.000000  206.259995  204.753738
# 2020-07-06  208.830002  211.130005  208.089996  210.699997  209.161301
#
#               Volume
# Date
# 2020-06-29  26701600
# 2020-06-30  34310300
# 2020-07-01  32061200
# 2020-07-02  29315800
# 2020-07-06  31897600

# %% [markdown]
# #### Let’s now check the variable statistics using the describe function.

# %%
StockData.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  225.000000  225.000000  225.000000  225.000000  225.000000
# mean   223.572178  225.951867  221.240356  223.686311  223.009755
# std     16.448298   16.287315   16.623774   16.489469   16.915758
# min    195.779999  198.529999  193.550003  198.440002  196.990829
# 25%    211.229996  213.320007  208.690002  211.009995  209.975388
# 50%    217.259995  219.690002  214.809998  217.690002  217.189774
# 75%    235.990005  238.000000  232.429993  235.770004  235.770004
# max    261.660004  263.190002  260.170013  261.970001  261.970001
#
#              Volume
# count  2.250000e+02
# mean   3.056009e+07
# std    1.000399e+07
# min    1.055060e+07
# 25%    2.383750e+07
# 50%    2.877420e+07
# 75%    3.406190e+07
# max    7.898300e+07

# %% [markdown]
# ### Let’s also see if the data contains any missing values

# %%
StockData.isnull().any()
# Out:
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %% [markdown]
# ## Creating candlestick chart

# %%
mf.plot(StockData, 
        type = 'candle',
        title = 'MSFT May 2020 walkthorugh',
        ylabel = 'MSFT Prices',
       figratio=(12,8))

# %% [markdown]
# ## Exploring styles of candlestick plots

# %%
mf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
# Applying binance style
mf.plot(StockData, 
        type = 'candle',
        style =  'binance',
        title = 'MSFT May 2020 walkthorugh',
        ylabel = 'MSFT Prices',
       figratio=(12,8))

# %% [markdown]
# ### Adding volume to candlestick chart

# %%
mf.plot(StockData, 
        type = 'candle',
        style =  'charles',
        title = 'MSFT May 2020 walkthorugh',
        ylabel = 'MSFT Prices',
       figratio=(12,8),
       volume = True )

# %% [markdown]
# ### Showing non-tranding data as well

# %%
mf.plot(StockData, 
        type = 'candle',
        style =  'charles',
        title = 'MSFT May 2020 walkthorugh',
        ylabel = 'MSFT Prices',
        figratio=(12,8),
       volume = True,
       show_nontrading = True)

# %% [markdown]
# ### Adding moving averages to candlestick chart

# %%
mf.plot(StockData, 
        type = 'candle',
        style =  'charles',
        title = 'MSFT May 2020 walkthorugh',
        ylabel = 'MSFT Prices',
        figratio=(12,8),
       volume = True,
       show_nontrading = True,
       ylabel_lower='Volume of \n traded shares',
       mav = 2)

# %% [markdown]
# ### The average lines makes it easier to find out the Ascending Triangle pattern which is shown below:

# %% [markdown]
# ![Screenshot%20%281874%29.png](attachment:Screenshot%20%281874%29.png)
